# %% [markdown]
# # DermaVision - Phase 5: TensorFlow Lite Optimization
#
# ## What is TensorFlow Lite?
#
# TensorFlow Lite (TFLite) is designed for mobile and edge devices.
#
# ## What is Quantization?
#
# Quantization reduces model size by converting 32-bit floats to 8-bit integers.
# - Model becomes 4x smaller
# - Inference becomes faster
# - Some accuracy may be lost
#
# ---

# %%
import tensorflow as tf
import numpy as np
import os
import shutil

BACKUP_DIR = 'backup/DermaVision'

# Load data
if os.path.exists('X_test.npy'):
    print("Loading from local...")
elif os.path.exists(os.path.join(BACKUP_DIR, 'X_test.npy')):
    print(f"Loading from backup ({BACKUP_DIR})...")
    for file in ['X_test.npy', 'y_test.npy', 'label_classes.npy']:
        shutil.copy(os.path.join(BACKUP_DIR, file), '.')
    # Also try to copy models if they exist in backup
    for model_file in ['fl_iid_model.keras', 'baseline_model.keras']:
        if os.path.exists(os.path.join(BACKUP_DIR, model_file)) and not os.path.exists(model_file):
            shutil.copy(os.path.join(BACKUP_DIR, model_file), '.')
else:
    print("ERROR: Data not found! Please run previous notebooks first.")

if os.path.exists('X_test.npy'):
    X_test = np.load('X_test.npy')
    y_test = np.load('y_test.npy')
    label_classes = np.load('label_classes.npy')

# Load best model (IID usually better)
if os.path.exists('fl_iid_model.keras'):
    model = tf.keras.models.load_model('fl_iid_model.keras')
    model_name = 'FL IID'
elif os.path.exists('baseline_model.keras'):
    model = tf.keras.models.load_model('baseline_model.keras')
    model_name = 'Baseline'
else:
    print("WARNING: No model found! Please train a model first.")
    model = None

if model:
    original_size = os.path.getsize(f'{model_name.lower().replace(" ", "_")}_model.keras' if 'FL' not in model_name else 'fl_iid_model.keras') / (1024*1024)
    print(f"Loaded {model_name} model ({original_size:.2f} MB)")
# Out:
# Loading from local...
# Loaded FL IID model (10.43 MB)
# c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\saving\saving_lib.py:797: UserWarning: Skipping variable loading for optimizer 'adam', because it has 114 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
# Evaluate original
if 'model' in locals() and model:
    original_loss, original_accuracy = model.evaluate(X_test, y_test, verbose=0)
    print(f"Original Accuracy: {original_accuracy*100:.2f}%")
# Out:
# Original Accuracy: 69.56%

# %%
# Convert to TFLite with quantization
if 'model' in locals() and model:
    converter = tf.lite.TFLiteConverter.from_keras_model(model)
    converter.optimizations = [tf.lite.Optimize.DEFAULT]

    print("Converting to TFLite...")
    tflite_model = converter.convert()

    tflite_path = 'dermavision_optimized.tflite'
    with open(tflite_path, 'wb') as f:
        f.write(tflite_model)

    tflite_size = os.path.getsize(tflite_path) / (1024*1024)
    print(f"Done: TFLite model saved ({tflite_size:.2f} MB)")
# Out:
# Converting to TFLite...
# INFO:tensorflow:Assets written to: C:\Users\Admin\AppData\Local\Temp\tmpefmqhux8\assets
# INFO:tensorflow:Assets written to: C:\Users\Admin\AppData\Local\Temp\tmpefmqhux8\assets
# Saved artifact at 'C:\Users\Admin\AppData\Local\Temp\tmpefmqhux8'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='input_layer')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   2610761591568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761592912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761590800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761592528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761593104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761592720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761594256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761594448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761593680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761591376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761591184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761595024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761595984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761595600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761593296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761594832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761595408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761595216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761596752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761593488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610761596560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851923536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851923728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851922960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851922384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851923344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851922576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851922768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851923152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851924688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851924112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851924304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851924496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851922000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851925648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851925072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851925264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851925456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851922192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851926608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851926992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851927184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851926224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851926800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851927760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851928144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851928336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851927376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851927952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851928912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851926416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851928528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851928720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851925840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851929872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851929296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851929488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851929680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851926032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851930832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851930256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851930448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851930640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851927568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851931792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851931216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851931408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851931600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851929104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851932752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851932176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851932368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851932560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851930064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851933712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851933136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851933328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851933520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851931024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851934672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851934096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851934288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851934480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851931984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851935632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851935056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851935248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851935440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851932944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851936592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851936016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851936208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851936400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851933904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851937552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851936976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851937168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851937744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851938128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851936784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851935824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851937360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857870352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851937936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610851934864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857870544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857869584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857869392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857869968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857871504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857870928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857871120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857871312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857870736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857872464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857871888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857872080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857872272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857870160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857873424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857872848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857873040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857873232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857869776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857874384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857873808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857874000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857874192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857871696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857875344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857874768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857874960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857875152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857872656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857876304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857875728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857875920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857876112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857873616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857877264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857876688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857876880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857877072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857874576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857878224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857877648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857877840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857878032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857875536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857879184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857878608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857878800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857878992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857876496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857880144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857879568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857879760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857879952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857877456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857881104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857880528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857880720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857880912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857878416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857882064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857881488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857881680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857881872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857879376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857883024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857882448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857882640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857882832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857880336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857883984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857883408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857883600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857883792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857881296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857884944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857884368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857884560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857885136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857885520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857884176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857883216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857884752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875319504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857885328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610857882256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875318544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875318928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875319120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875319312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875320464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875319888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875320080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875320272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875318352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875321424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875320848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875321040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875321232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875318736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875322384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875321808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875322000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875322192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875319696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875323344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875322768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875322960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875323152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875320656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875324304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875323728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875323920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875324112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875321616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875325264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875324688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875324880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875325072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875322576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875326224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875325648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875325840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875326032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875323536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875327184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875326608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875326800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875326992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875324496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875328144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875327568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875327760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875327952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875325456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875329104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875328528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875328720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875328912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875326416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875330064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875329488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875329680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875329872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875327376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875331024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875330448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875330640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875330832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875328336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875331984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875331408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875331600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875331792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875329296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875332944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875332368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875330256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875332560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2610875333904: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Done: TFLite model saved (2.71 MB)

# %%
import matplotlib.pyplot as plt

if 'tflite_size' in locals():
    size_reduction = ((original_size - tflite_size) / original_size) * 100
    compression = original_size / tflite_size

    print("SIZE COMPARISON")
    print("=" * 40)
    print(f"Original: {original_size:.2f} MB")
    print(f"TFLite:   {tflite_size:.2f} MB")
    print(f"Reduction: {size_reduction:.1f}% ({compression:.1f}x smaller)")

    plt.figure(figsize=(8, 5))
    plt.bar(['Original', 'TFLite'], [original_size, tflite_size], color=['#2196F3', '#4CAF50'])
    plt.title('Model Size Comparison')
    plt.ylabel('Size (MB)')
    plt.savefig('model_size_comparison.png', dpi=100)
    plt.show()
# Out:
# SIZE COMPARISON
# ========================================
# Original: 10.43 MB
# TFLite:   2.71 MB
# Reduction: 74.1% (3.9x smaller)

# %%
# Test TFLite model
if 'tflite_path' in locals() and os.path.exists(tflite_path):
    interpreter = tf.lite.Interpreter(model_path=tflite_path)
    interpreter.allocate_tensors()
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    def tflite_predict(image):
        if len(image.shape) == 3:
            image = np.expand_dims(image, axis=0)
        image = image.astype(np.float32)
        interpreter.set_tensor(input_details[0]['index'], image)
        interpreter.invoke()
        return interpreter.get_tensor(output_details[0]['index'])[0]

    # Evaluate
    correct = 0
    for i in range(len(X_test)):
        pred = tflite_predict(X_test[i])
        if np.argmax(pred) == np.argmax(y_test[i]):
            correct += 1

    tflite_accuracy = correct / len(X_test)
    print(f"TFLite Accuracy: {tflite_accuracy*100:.2f}%")
    print(f"Accuracy Drop: {(original_accuracy - tflite_accuracy)*100:.2f}%")
# Out:
# c:\Users\Admin\anaconda3\Lib\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
# TFLite Accuracy: 70.00%
# Accuracy Drop: -0.44%

# %%
# Save results
if 'tflite_path' in locals():
    with open('tflite_results.txt', 'w') as f:
        f.write("TFLITE OPTIMIZATION RESULTS\n")
        f.write(f"Original Size: {original_size:.2f} MB\n")
        f.write(f"TFLite Size: {tflite_size:.2f} MB\n")
        f.write(f"Compression: {compression:.1f}x\n")
        f.write(f"Original Accuracy: {original_accuracy*100:.2f}%\n")
        f.write(f"TFLite Accuracy: {tflite_accuracy*100:.2f}%\n")

    # Backup
    os.makedirs(BACKUP_DIR, exist_ok=True)
    
    shutil.copy('dermavision_optimized.tflite', BACKUP_DIR)
    shutil.copy('model_size_comparison.png', BACKUP_DIR)
    shutil.copy('tflite_results.txt', BACKUP_DIR)

    print(f"Done: Backed up to {BACKUP_DIR}!")
# Out:
# Done: Backed up to backup/DermaVision!

# %% [markdown]
# ---
#
# ## Phase 5 Complete
#
# **Summary**: Model optimized for mobile deployment with minimal accuracy loss.
#
# **Next**: Run `06_EdgeDeployment.ipynb` to test the final model.
